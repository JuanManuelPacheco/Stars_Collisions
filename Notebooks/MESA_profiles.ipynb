# %%
import numpy as np

import matplotlib as mpl
mpl.rcParams['agg.path.chunksize'] = 5000
import matplotlib.pyplot as plt
plt.rcParams.update({'font.size': 25})

# %%
# Path where the MESA profiles are located.
data_path = '/home/juanmanuel/Documents/Master/Thesis/Simulations/MESA'

# %%
lr_58Z,m_58Z,h_58Z,he_58Z,c_58Z = np.genfromtxt('{}/star_MESA_58_ZAMS'.format(data_path),
                                        dtype='float', usecols=(2,1,6,7,8) ,skip_header=6,
                                        comments="#", unpack=True)

lr_58T,m_58T,h_58T,he_58T,c_58T = np.genfromtxt('{}/star_MESA_58_TAMS'.format(data_path),
                                        dtype='float', usecols=(2,1,6,7,8) ,skip_header=6,
                                        comments="#", unpack=True)

lr_58H,m_58H,h_58H,he_58H,c_58H = np.genfromtxt('{}/star_MESA_58_TCHeB'.format(data_path),
                                        dtype='float', usecols=(2,1,6,7,8) ,skip_header=6,
                                        comments="#", unpack=True)

lr_58C,m_58C,h_58C,he_58C,c_58C = np.genfromtxt('{}/star_MESA_58_TCCB'.format(data_path),
                                        dtype='float', usecols=(2,1,6,7,8) ,skip_header=6,
                                        comments="#", unpack=True)

# %%
lr_65Z,m_65Z,h_65Z,he_65Z,c_65Z  = np.genfromtxt('{}/star_MESA_65_ZAMS'.format(data_path),
                                        dtype='float', usecols=(2,1,6,7,8) ,skip_header=6,
                                        comments="#", unpack=True)

lr_65T,m_65T,h_65T,he_65T,c_65T = np.genfromtxt('{}/star_MESA_65_TAMS'.format(data_path),
                                        dtype='float', usecols=(2,1,6,7,8) ,skip_header=6,
                                        comments="#", unpack=True)

lr_65H,m_65H,h_65H,he_65H,c_65H = np.genfromtxt('{}/star_MESA_65_TCHeB'.format(data_path),
                                        dtype='float', usecols=(2,1,6,7,8) ,skip_header=6,
                                        comments="#", unpack=True)

lr_65C,m_65C,h_65C,he_65C,c_65C = np.genfromtxt('{}/star_MESA_65_TCCB'.format(data_path),
                                        dtype='float', usecols=(2,1,6,7,8) ,skip_header=6,
                                        comments="#", unpack=True)

# %%
lr_75Z,m_75Z,h_75Z,he_75Z,c_75Z = np.genfromtxt('{}/star_MESA_75_ZAMS'.format(data_path),
                                        dtype='float', usecols=(2,1,6,7,8) ,skip_header=6,
                                        comments="#", unpack=True)

lr_75T,m_75T,h_75T,he_75T,c_75T = np.genfromtxt('{}/star_MESA_75_TAMS'.format(data_path),
                                        dtype='float', usecols=(2,1,6,7,8) ,skip_header=6,
                                        comments="#", unpack=True)

lr_75H,m_75H,h_75H,he_75H,c_75H = np.genfromtxt('{}/star_MESA_75_TCHeB'.format(data_path),
                                        dtype='float', usecols=(2,1,6,7,8) ,skip_header=6,
                                        comments="#", unpack=True)

lr_75C,m_75C,h_75C,he_75C,c_75C = np.genfromtxt('{}/star_MESA_75_TCCB'.format(data_path),
                                        dtype='float', usecols=(2,1,6,7,8) ,skip_header=6,
                                        comments="#", unpack=True)

# %%
lr_85Z,m_85Z,h_85Z,he_85Z,c_85Z = np.genfromtxt('{}/star_MESA_85_ZAMS'.format(data_path),
                                        dtype='float', usecols=(2,1,6,7,8) ,skip_header=6,
                                        comments="#", unpack=True)

lr_85T,m_85T,h_85T,he_85T,c_85T = np.genfromtxt('{}/star_MESA_85_TAMS'.format(data_path),
                                        dtype='float', usecols=(2,1,6,7,8) ,skip_header=6,
                                        comments="#", unpack=True)

lr_85H,m_85H,h_85H,he_85H,c_85H = np.genfromtxt('{}/star_MESA_85_TCHeB'.format(data_path),
                                        dtype='float', usecols=(2,1,6,7,8) ,skip_header=6,
                                        comments="#", unpack=True)

lr_85C,m_85C,h_85C,he_85C,c_85C = np.genfromtxt('{}/star_MESA_85_TCCB'.format(data_path),
                                        dtype='float', usecols=(2,1,6,7,8) ,skip_header=6,
                                        comments="#", unpack=True)

# %%
tens_58Z=lr_58Z*0.+10.
tens_58T=lr_58T*0.+10.
tens_58C=lr_58C*0.+10.
tens_58H=lr_58H*0.+10.

r_58Z=np.power(tens_58Z,lr_58Z)
r_58T=np.power(tens_58T,lr_58T)
r_58C=np.power(tens_58C,lr_58C)
r_58H=np.power(tens_58H,lr_58H)

r_58Z=np.flip(r_58Z)
h_58Z=np.flip(h_58Z)
he_58Z=np.flip(he_58Z)
c_58Z=np.flip(c_58Z)

r_58T=np.flip(r_58T)
h_58T=np.flip(h_58T)
he_58T=np.flip(he_58T)
c_58T=np.flip(c_58T)

r_58C=np.flip(r_58C)
h_58C=np.flip(h_58C)
he_58C=np.flip(he_58C)
c_58C=np.flip(c_58C)

r_58H=np.flip(r_58H)
h_58H=np.flip(h_58H)
he_58H=np.flip(he_58H)
c_58H=np.flip(c_58H)

# %%
tens_65Z=lr_65Z*0.+10.
tens_65T=lr_65T*0.+10.
tens_65C=lr_65C*0.+10.
tens_65H=lr_65H*0.+10.

r_65Z=np.power(tens_65Z,lr_65Z)
r_65T=np.power(tens_65T,lr_65T)
r_65C=np.power(tens_65C,lr_65C)
r_65H=np.power(tens_65H,lr_65H)

r_65Z=np.flip(r_65Z)
h_65Z=np.flip(h_65Z)
he_65Z=np.flip(he_65Z)
c_65Z=np.flip(c_65Z)

r_65T=np.flip(r_65T)
h_65T=np.flip(h_65T)
he_65T=np.flip(he_65T)
c_65T=np.flip(c_65T)

r_65C=np.flip(r_65C)
h_65C=np.flip(h_65C)
he_65C=np.flip(he_65C)
c_65C=np.flip(c_65C)

r_65H=np.flip(r_65H)
h_65H=np.flip(h_65H)
he_65H=np.flip(he_65H)
c_65ZH=np.flip(c_65H)

# %%
tens_75Z=lr_75Z*0.+10.
tens_75T=lr_75T*0.+10.
tens_75C=lr_75C*0.+10.
tens_75H=lr_75H*0.+10.

r_75Z=np.power(tens_75Z,lr_75Z)
r_75T=np.power(tens_75T,lr_75T)
r_75C=np.power(tens_75C,lr_75C)
r_75H=np.power(tens_75H,lr_75H)

r_75Z=np.flip(r_75Z)
h_75Z=np.flip(h_75Z)
he_75Z=np.flip(he_75Z)
c_75Z=np.flip(c_75Z)

r_75T=np.flip(r_75T)
h_75T=np.flip(h_75T)
he_75T=np.flip(he_75T)
c_75T=np.flip(c_75T)

r_75C=np.flip(r_75C)
h_75C=np.flip(h_75C)
he_75C=np.flip(he_75C)
c_75C=np.flip(c_75C)

r_75H=np.flip(r_75H)
h_75H=np.flip(h_75H)
he_75H=np.flip(he_75H)
c_75H=np.flip(c_75H)

# %%
tens_85Z=lr_85Z*0.+10.
tens_85T=lr_85T*0.+10.
tens_85C=lr_85C*0.+10.
tens_85H=lr_85H*0.+10.

r_85Z=np.power(tens_85Z,lr_85Z)
r_85T=np.power(tens_85T,lr_85T)
r_85C=np.power(tens_85C,lr_85C)
r_85H=np.power(tens_85H,lr_85H)

r_85Z=np.flip(r_85Z)
h_85Z=np.flip(h_85Z)
he_85Z=np.flip(he_85Z)
c_85Z=np.flip(c_85Z)

r_85T=np.flip(r_85T)
h_85T=np.flip(h_85T)
he_85T=np.flip(he_85T)
c_85T=np.flip(c_85T)

r_85C=np.flip(r_85C)
h_85C=np.flip(h_85C)
he_85C=np.flip(he_85C)
c_85C=np.flip(c_85C)

r_85H=np.flip(r_85H)
h_85H=np.flip(h_85H)
he_85H=np.flip(he_85H)
c_85H=np.flip(c_85H)

# %%
fig, axs=plt.subplots(nrows=4,  ncols=4, figsize=(28,25))
fig.subplots_adjust(hspace=0.3)

axs[0,0].set_title(r'$M_{ZAMS} = 58$ $M_{\odot}$', fontsize=30)
axs[0,0].plot(r_58Z,h_58Z,'-r', linewidth=3.5, label = r'$^1$H')
axs[0,0].plot(r_58Z,he_58Z,'--b', linewidth=3.5, label = '$^4$He')
axs[0,0].plot(r_58Z,c_58Z,'-.k', linewidth=3.5, label = '$^{12}$C')
axs[0,0].set_ylabel(r'$M$ $[\%]$', fontsize = 28)
axs[0,0].legend(fontsize = 20, loc=0)

axs[0,1].set_title(r'$M_{TAMS} = 58$ $M_{\odot}$', fontsize=30)
axs[0,1].plot(r_58T,h_58T,'-r', linewidth=3.5, label = r'$^1$H')
axs[0,1].plot(r_58T,he_58T,'--b', linewidth=3.5, label = '$^4$He')
axs[0,1].plot(r_58T,c_58T,'-.k', linewidth=3.5, label = '$^{12}$C')
axs[0,1].legend(fontsize = 20, loc=0)

axs[0,2].set_title(r'$M_{CHeB} = 58$ $M_{\odot}$', fontsize=30)
axs[0,2].plot(r_58H,h_58H,'-r', linewidth=3.5, label = r'$^1$H')
axs[0,2].plot(r_58H,he_58H,'--b', linewidth=3.5, label = '$^4$He')
axs[0,2].plot(r_58H,c_58H,'-.k', linewidth=3., label = '$^{12}$C')
axs[0,2].legend(fontsize = 20, loc=0)
axs[0,2].set_xscale('log')

axs[0,3].set_title(r'$M_{CCB} = 58$ $M_{\odot}$', fontsize=30)
axs[0,3].plot(r_58C,h_58C,'-r', linewidth=3.5, label = r'$^1$H')
axs[0,3].plot(r_58C,he_58C,'--b', linewidth=3.5, label = '$^4$He')
axs[0,3].plot(r_58C,c_58C,'-.k', linewidth=3.5, label = '$^{12}$C')
axs[0,3].legend(fontsize = 20, loc=0)
axs[0,3].set_xscale('log')

axs[1,0].set_title(r'$M_{ZAMS} = 65$ $M_{\odot}$', fontsize=30)
axs[1,0].plot(r_65Z,h_65Z,'-r', linewidth=3.5, label = r'$^1$H')
axs[1,0].plot(r_65Z,he_65Z,'--b', linewidth=3.5, label = '$^4$He')
axs[1,0].plot(r_65Z,c_65Z,'-.k', linewidth=3.5, label = '$^{12}$C')
axs[1,0].set_ylabel(r'$M$ $[\%]$', fontsize = 28)
axs[1,0].legend(fontsize = 20, loc=0)

axs[1,1].set_title(r'$M_{TAMS} = 65$ $M_{\odot}$', fontsize=30)
axs[1,1].plot(r_65T,h_65T,'-r', linewidth=3.5, label = r'$^1$H')
axs[1,1].plot(r_65T,he_65T,'--b', linewidth=3.5, label = '$^4$He')
axs[1,1].plot(r_65T,c_65T,'-.k', linewidth=3.5, label = '$^{12}$C')
axs[1,1].legend(fontsize = 20, loc=0)

axs[1,2].set_title(r'$M_{CHeB} = 65$ $M_{\odot}$', fontsize=30)
axs[1,2].plot(r_65H,h_65H,'-r', linewidth=3.5, label = r'$^1$H')
axs[1,2].plot(r_65H,he_65H,'--b', linewidth=3.5, label = '$^4$He')
axs[1,2].plot(r_65H,c_65H,'-.k', linewidth=3.5, label = '$^{12}$C')
axs[1,2].legend(fontsize = 20, loc=0)
axs[1,2].set_xscale('log')

axs[1,3].set_title(r'$M_{CCB} = 65$ $M_{\odot}$', fontsize=30)
axs[1,3].plot(r_65C,h_65C,'-r', linewidth=3.5, label = r'$^1$H')
axs[1,3].plot(r_65C,he_65C,'--b', linewidth=3.5, label = '$^4$He')
axs[1,3].plot(r_65C,c_65C,'-.k', linewidth=3.5, label = '$^{12}$C')
axs[1,3].legend(fontsize = 20, loc=0)
axs[1,3].set_xscale('log')

axs[2,0].set_title(r'$M_{ZAMS} = 75$ $M_{\odot}$', fontsize=30)
axs[2,0].plot(r_75Z,h_75Z,'-r', linewidth=3.5, label = r'$^1$H')
axs[2,0].plot(r_75Z,he_75Z,'--b', linewidth=3.5, label = '$^4$He')
axs[2,0].plot(r_75Z,c_75Z,'-.k', linewidth=3.5, label = '$^{12}$C')
axs[2,0].set_ylabel(r'$M$ $[\%]$', fontsize = 28)
axs[2,0].legend(fontsize = 20, loc=0)

axs[2,1].set_title(r'$M_{TAMS} = 75$ $M_{\odot}$', fontsize=30)
axs[2,1].plot(r_75T,h_75T,'-r', linewidth=3.5, label = r'$^1$H')
axs[2,1].plot(r_75T,he_75T,'--b', linewidth=3.5, label = '$^4$He')
axs[2,1].plot(r_75T,c_75T,'-.k', linewidth=3.5, label = '$^{12}$C')
axs[2,1].legend(fontsize = 20, loc=0)

axs[2,2].set_title(r'$M_{CHeB} = 75$ $M_{\odot}$', fontsize=30)
axs[2,2].plot(r_75H,h_75H,'-r', linewidth=3.5, label = r'$^1$H')
axs[2,2].plot(r_75H,he_75H,'--b', linewidth=3.5, label = '$^4$He')
axs[2,2].plot(r_75H,c_75H,'-.k', linewidth=3.5, label = '$^{12}$C')
axs[2,2].legend(fontsize = 20, loc=0)
axs[2,2].set_xscale('log')

axs[2,3].set_title(r'$M_{CCB} = 75$ $M_{\odot}$', fontsize=30)
axs[2,3].plot(r_75C,h_75C,'-r', linewidth=3.5, label = r'$^1$H')
axs[2,3].plot(r_75C,he_75C,'--b', linewidth=3.5, label = '$^4$He')
axs[2,3].plot(r_75C,c_75C,'-.k', linewidth=3.5, label = '$^{12}$C')
axs[2,3].legend(fontsize = 20, loc=0)
axs[2,3].set_xscale('log')

axs[3,0].set_title(r'$M_{ZAMS} = 85$ $M_{\odot}$', fontsize=30)
axs[3,0].plot(r_85Z,h_85Z,'-r', linewidth=3.5, label = r'$^1$H')
axs[3,0].plot(r_85Z,he_85Z,'--b', linewidth=3.5, label = '$^4$He')
axs[3,0].plot(r_85Z,c_85Z,'-.k', linewidth=3.5, label = '$^{12}$C')
axs[3,0].set_ylabel(r'$M$ $[\%]$', fontsize = 28)
axs[3,0].set_xlabel(r'$R$ $[R_{\odot}]$', fontsize = 28)
axs[3,0].legend(fontsize = 20, loc=0)

axs[3,1].set_title(r'$M_{TAMS} = 85$ $M_{\odot}$', fontsize=30)
axs[3,1].plot(r_85T,h_85T,'-r', linewidth=3.5, label = r'$^1$H')
axs[3,1].plot(r_85T,he_85T,'--b', linewidth=3.5, label = '$^4$He')
axs[3,1].plot(r_85T,c_85T,'-.k', linewidth=3.5, label = '$^{12}$C')
axs[3,1].set_xlabel(r'$R$ $[R_{\odot}]$', fontsize = 28)
axs[3,1].legend(fontsize = 20, loc=0)

axs[3,2].set_title(r'$M_{CHeB} = 85$ $M_{\odot}$', fontsize=30)
axs[3,2].plot(r_85H,h_85H,'-r', linewidth=3.5, label = r'$^1$H')
axs[3,2].plot(r_85H,he_85H,'--b', linewidth=3.5, label = '$^4$He')
axs[3,2].plot(r_85H,c_85H,'-.k', linewidth=3.5, label = '$^{12}$C')
axs[3,2].set_xlabel(r'$R$ $[R_{\odot}]$', fontsize = 28)
axs[3,2].legend(fontsize = 20, loc=0)
axs[3,2].set_xscale('log')

axs[3,3].set_title(r'$M_{CCB} = 85$ $M_{\odot}$', fontsize=30)
axs[3,3].plot(r_85C,h_85C,'-r', linewidth=3.5, label = r'$^1$H')
axs[3,3].plot(r_85C,he_85C,'--b', linewidth=3.5, label = '$^4$He')
axs[3,3].plot(r_85C,c_85C,'-.k', linewidth=3.5, label = '$^{12}$C')
axs[3,3].set_xlabel(r'$R$ $[R_{\odot}]$', fontsize = 28)
axs[3,3].legend(fontsize = 20, loc=0)
axs[3,3].set_xscale('log')

plt.tight_layout()
plt.show()
